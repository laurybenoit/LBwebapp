# %%
import pandas as pd 
import numpy as np
import os
import sqlalchemy

# %%
beneficiary_file = "Test_Beneficiarydata-1542969243754.csv"
beneficary_df = pd.read_csv(beneficiary_file)
beneficary_df.head()
# Out:
#       BeneID         DOB         DOD  Gender  Race RenalDiseaseIndicator  \
# 0  BENE11001  1943-01-01         NaN       1     1                     0
# 1  BENE11007  1940-09-01  2009-12-01       1     2                     0
# 2  BENE11010  1936-07-01         NaN       2     1                     0
# 3  BENE11011  1914-03-01         NaN       2     2                     0
# 4  BENE11014  1938-04-01         NaN       2     1                     Y
#
#    State  County  NoOfMonths_PartACov  NoOfMonths_PartBCov  ...  \
# 0     39     230                   12                   12  ...
# 1     45     610                   12                   12  ...
# 2     41      30                   12                   12  ...
# 3      1     360                   12                   12  ...
# 4     45     780                   12                   12  ...
#
#    ChronicCond_Depression  ChronicCond_Diabetes  ChronicCond_IschemicHeart  \
# ...

# %%
beneficary_df.columns
# Out:
# Index(['BeneID', 'DOB', 'DOD', 'Gender', 'Race', 'RenalDiseaseIndicator',
#        'State', 'County', 'NoOfMonths_PartACov', 'NoOfMonths_PartBCov',
#        'ChronicCond_Alzheimer', 'ChronicCond_Heartfailure',
#        'ChronicCond_KidneyDisease', 'ChronicCond_Cancer',
#        'ChronicCond_ObstrPulmonary', 'ChronicCond_Depression',
#        'ChronicCond_Diabetes', 'ChronicCond_IschemicHeart',
#        'ChronicCond_Osteoporasis', 'ChronicCond_rheumatoidarthritis',
#        'ChronicCond_stroke', 'IPAnnualReimbursementAmt',
#        'IPAnnualDeductibleAmt', 'OPAnnualReimbursementAmt',
#        'OPAnnualDeductibleAmt'],
#       dtype='object')

# %%
beneficary_df.describe(include='all').T
# Out:
#                                  count unique         top   freq     mean  \
# BeneID                           63968  63968  BENE127949      1      NaN
# DOB                              63968    900  1940-03-01    265      NaN
# DOD                                574     12  2009-12-01     92      NaN
# Gender                           63968    NaN         NaN    NaN  1.57405
# Race                             63968    NaN         NaN    NaN  1.25022
# RenalDiseaseIndicator            63968      2           0  53408      NaN
# State                            63968    NaN         NaN    NaN  26.2987
# County                           63968    NaN         NaN    NaN  368.598
# NoOfMonths_PartACov              63968    NaN         NaN    NaN  11.9189
# NoOfMonths_PartBCov              63968    NaN         NaN    NaN  11.9282
# ChronicCond_Alzheimer            63968    NaN         NaN    NaN  1.63257
# ChronicCond_Heartfailure         63968    NaN         NaN    NaN  1.45745
# ...

# %%
inpatient_file = "Test_Inpatientdata-1542969243754.csv"
inpatient_df = pd.read_csv(inpatient_file)
inpatient_df.head(100)
# Out:
#        BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0   BENE11014  CLM67387   2009-09-09  2009-09-16  PRV57070
# 1   BENE11017  CLM31237   2008-12-25  2009-01-08  PRV54750
# 2   BENE11026  CLM78930   2009-12-09  2009-12-13  PRV53758
# 3   BENE11031  CLM56810   2009-06-23  2009-07-06  PRV55825
# 4   BENE11085  CLM34625   2009-01-20  2009-01-31  PRV52338
# ..        ...       ...          ...         ...       ...
# 95  BENE12512  CLM76961   2009-11-23  2009-11-27  PRV55380
# 96  BENE12514  CLM56223   2009-06-19  2009-06-20  PRV54948
# 97  BENE12531  CLM69230   2009-09-23  2009-10-06  PRV53275
# 98  BENE12584  CLM80384   2009-12-22  2009-12-24  PRV51597
# 99  BENE12585  CLM57816   2009-06-30  2009-07-02  PRV52655
#
#     InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                     9000          PHY317786          PHY427017
# 1                    14000          PHY314656          PHY426644
# ...

# %%
outpatient_file = "Test_Outpatientdata-1542969243754.csv"
outpatient_df = pd.read_csv(outpatient_file)
outpatient_df.head(10)
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM392397   2009-06-02  2009-06-02  PRV55962
# 1  BENE11001  CLM430760   2009-06-23  2009-06-23  PRV56112
# 2  BENE11007  CLM233081   2009-03-07  2009-03-07  PRV56979
# 3  BENE11007  CLM496381   2009-07-29  2009-07-29  PRV56573
# 4  BENE11007  CLM521391   2009-08-12  2009-08-12  PRV56573
# 5  BENE11007  CLM537365   2009-08-21  2009-08-21  PRV56612
# 6  BENE11007  CLM646966   2009-10-24  2009-10-24  PRV56678
# 7  BENE11007  CLM689394   2009-11-19  2009-11-19  PRV56565
# 8  BENE11010  CLM140012   2009-01-16  2009-01-16  PRV56204
# 9  BENE11010  CLM165765   2009-01-30  2009-01-30  PRV56204
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY347633                NaN
# 1                      30          PHY381777                NaN
# 2                     200          PHY425311                NaN
# ...

# %%
provider_file = "Test-1542969243754.csv"
provider_df = pd.read_csv(provider_file)
provider_df.head(100)
# Out:
#     Provider
# 0   PRV51002
# 1   PRV51006
# 2   PRV51009
# 3   PRV51010
# 4   PRV51018
# ..       ...
# 95  PRV51461
# 96  PRV51463
# 97  PRV51473
# 98  PRV51481
# 99  PRV51485
#
# [100 rows x 1 columns]

# %%
test_data1 = pd.merge(inpatient_df, outpatient_df, how='outer')
test_data1.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11014  CLM67387   2009-09-09  2009-09-16  PRV57070
# 1  BENE11017  CLM31237   2008-12-25  2009-01-08  PRV54750
# 2  BENE11026  CLM78930   2009-12-09  2009-12-13  PRV53758
# 3  BENE11031  CLM56810   2009-06-23  2009-07-06  PRV55825
# 4  BENE11085  CLM34625   2009-01-20  2009-01-31  PRV52338
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                    9000          PHY317786          PHY427017
# 1                   14000          PHY314656          PHY426644
# 2                    2000          PHY349495                NaN
# 3                   16000          PHY429538          PHY371893
# 4                   19000          PHY397161                NaN
#
#   OtherPhysician AdmissionDt  ... ClmDiagnosisCode_7  ClmDiagnosisCode_8  \
# 0            NaN  2009-09-09  ...               5990                 570
# 1            NaN  2008-12-25  ...               4549               29570
# ...

# %%
test_data2 = pd.merge(test_data1, beneficary_df, how='outer')
test_data2.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11014   CLM67387   2009-09-09  2009-09-16  PRV57070
# 1  BENE11014  CLM731858   2009-12-16  2009-12-16  PRV56558
# 2  BENE11017   CLM31237   2008-12-25  2009-01-08  PRV54750
# 3  BENE11026   CLM78930   2009-12-09  2009-12-13  PRV53758
# 4  BENE11031   CLM56810   2009-06-23  2009-07-06  PRV55825
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                    9000          PHY317786          PHY427017
# 1                      60          PHY331420          PHY331420
# 2                   14000          PHY314656          PHY426644
# 3                    2000          PHY349495                NaN
# 4                   16000          PHY429538          PHY371893
#
#   OtherPhysician AdmissionDt  ... ChronicCond_Depression  \
# 0            NaN  2009-09-09  ...                      1
# 1      PHY428520         NaN  ...                      1
# ...

# %%
test_data2.shape
# Out:
# (135392, 54)

# %%
test_data2.describe(include=[np.number]).T
# Out:
#                                     count         mean           std     min  \
# InscClaimAmtReimbursed           135392.0   981.307906   3788.177532     0.0
# DeductibleAmtPaid                135196.0    76.499194    270.779562     0.0
# ClmProcedureCode_1                 5467.0  5905.430766   3057.976988    14.0
# ClmProcedureCode_2                 1263.0  4138.790182   2042.016095    42.0
# ClmProcedureCode_3                  225.0  4182.213333   2165.057828   185.0
# ClmProcedureCode_4                   29.0  4509.931034   2571.379659   260.0
# ClmProcedureCode_5                    2.0  7055.500000   4124.553855  4139.0
# ClmProcedureCode_6                    0.0          NaN           NaN     NaN
# Gender                           135392.0     1.576231      0.494157     1.0
# Race                             135392.0     1.240605      0.695578     1.0
# State                            135392.0    26.904285     14.651997     1.0
# ...

# %%
test_data2.describe(include=[np.object])
# Out:
#             BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# count       135392     135392       135392      135392    135392
# unique       63968     135392          392         365      1353
# top     BENE103720  CLM719755   2009-04-04  2009-03-29  PRV56573
# freq            25          1          440         446      3250
#
#        AttendingPhysician OperatingPhysician OtherPhysician AdmissionDt  \
# count              135045              27193          48632        9551
# unique              21555               8970          12096         392
# top             PHY378872          PHY356259      PHY344080  2009-02-01
# freq                  939                170           1205          40
#
#        ClmAdmitDiagnosisCode  ... ClmDiagnosisCode_4 ClmDiagnosisCode_5  \
# count                  35356  ...              39617              26798
# unique                  2622  ...               2817               2475
# ...

# %%
test_data2.sample(20)
# Out:
#             BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 102824  BENE117305  CLM190583   2009-02-12  2009-02-12  PRV52613
# 129628  BENE151688  CLM591305   2009-09-21  2009-09-21  PRV56678
# 66192    BENE70098  CLM235325   2009-03-08  2009-03-08  PRV54974
# 124669  BENE145368  CLM505333   2009-08-03  2009-08-03  PRV54751
# 20786    BENE12288  CLM130804   2009-01-11  2009-01-11  PRV52080
# 84043    BENE92989  CLM200592   2009-02-17  2009-02-17  PRV56612
# 36647    BENE32552  CLM359733   2009-05-15  2009-05-17  PRV51853
# 73940    BENE80061  CLM535156   2009-08-20  2009-08-20  PRV51520
# 102236  BENE116505  CLM694843   2009-11-22  2009-11-22  PRV52083
# 105447  BENE120654  CLM129647   2009-01-10  2009-01-10  PRV51939
# 117797  BENE136490  CLM525720   2009-08-14  2009-08-14  PRV57606
# 122293  BENE142390  CLM115215   2009-01-02  2009-01-02  PRV55476
# 116222  BENE134532  CLM185174   2009-02-09  2009-02-09  PRV57068
# ...

# %%
test_data3 = test_data2.drop_duplicates()
test_data3.columns
# Out:
# Index(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
#        'OtherPhysician', 'AdmissionDt', 'ClmAdmitDiagnosisCode',
#        'DeductibleAmtPaid', 'DischargeDt', 'DiagnosisGroupCode',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
#        'ClmProcedureCode_6', 'DOB', 'DOD', 'Gender', 'Race',
#        'RenalDiseaseIndicator', 'State', 'County', 'NoOfMonths_PartACov',
#        'NoOfMonths_PartBCov', 'ChronicCond_Alzheimer',
#        'ChronicCond_Heartfailure', 'ChronicCond_KidneyDisease',
#        'ChronicCond_Cancer', 'ChronicCond_ObstrPulmonary',
# ...

# %%
test_data3.nunique()
# Out:
# BeneID                              63968
# ClaimID                            135392
# ClaimStartDt                          392
# ClaimEndDt                            365
# Provider                             1353
# InscClaimAmtReimbursed                308
# AttendingPhysician                  21555
# OperatingPhysician                   8970
# OtherPhysician                      12096
# AdmissionDt                           392
# ClmAdmitDiagnosisCode                2622
# DeductibleAmtPaid                      15
# DischargeDt                           365
# DiagnosisGroupCode                    712
# ClmDiagnosisCode_1                   8369
# ClmDiagnosisCode_2                   3610
# ClmDiagnosisCode_3                   3202
# ClmDiagnosisCode_4                   2817
# ClmDiagnosisCode_5                   2475
# ClmDiagnosisCode_6                   2181
# ClmDiagnosisCode_7                   1947
# ClmDiagnosisCode_8                   1792
# ...

# %%
test_data3.duplicated(subset=['Provider'])
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 135387     True
# 135388     True
# 135389     True
# 135390     True
# 135391     True
# Length: 135392, dtype: bool
